# %%
1+2
# Out:
# 3

# %% [markdown]
# hello world
# # hello world
# ## hello world
# **hello world**
#
#
# ```
# print("Haii")
# ```
#
# ```
# print("My name ")
# ```

# %%
print("Hello world")
# Out:
# Hello world
