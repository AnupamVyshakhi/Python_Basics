# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print(15+10)
# Out:
# 25

# %%
print("Hello"+"World")
# Out:
# HelloWorld

# %%
x=10
y=20
x,y=y,x
print(x)
# Out:
# 20

# %%
a=3.14
print(int(a))
# Out:
# 3

# %%
li=[1,2,3]
li.index(2)
# Out:
# 1
