# %% [markdown]
# #**1.PRINT**

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("First Line")
print("Second Line")
# Out:
# First Line
# Second Line

# %% [markdown]
# **SOME COMMON ERRORS**

# %%
Print("My name is Anupam")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6295ab2601dd> in <cell line: 1>()
# ----> 1 Print("My name is Anupam")
#
# NameError: name 'Print' is not defined

# %%
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
print"My name is Anupam"
# Out:
#   File "<ipython-input-5-5edbb8ea7554>", line 1
#     print"My name is Anupam"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
print("My name is
Anupam")
# Out:
#   File "<ipython-input-7-2614849875fa>", line 1
#     print("My name is
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ***For getting a line break we use """***

# %%
print("""My name is
Anupam""")
# Out:
# My name is
# Anupam

# %% [markdown]
# **Print the given statement:-**My name is "Anupam"

# %%
print("My name is "Anupam"")
# Out:
#   File "<ipython-input-9-9d2ad250818d>", line 1
#     print("My name is "Anupam"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('My name is "Anupam"')
# Out:
# My name is "Anupam"

# %% [markdown]
# **Print the given statement:-**My name is 'Anupam'

# %%
print("My name is 'Anupam'")
# Out:
# My name is 'Anupam'

# %% [markdown]
# #**2.COMMENTS**

# %%
#This is a comment

# %%
#This is a comment
#Below is a code for printing your NAME
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
"""This is a multiline comment"""
print("My name is Anupam")
# Out:
# My name is Anupam

# %% [markdown]
# #**3.INDENTATION**

# %%
print("Hai")
 print("Anupam")
# Out:
#   File "<ipython-input-15-5c3af8c397be>", line 2
#     print("Anupam")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **Python is strict about INDENTATION**

# %%
print("Hai")
print("Anupam")
# Out:
# Hai
# Anupam
