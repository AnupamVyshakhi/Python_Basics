# %% [markdown]
# #**1.PRINT**

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
print("FIRST LINE")
print("SECOND LINE")
# Out:
# FIRST LINE
# SECOND LINE

# %% [markdown]
# **Some common errors**

# %%
Print("My name is Anuapm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e00322cf752> in <cell line: 1>()
# ----> 1 Print("My nam eis Anuapm")
#
# NameError: name 'Print' is not defined

# %%
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
print"My name is Anupam"
# Out:
#   File "<ipython-input-4-5edbb8ea7554>", line 1
#     print"My name is Anupam"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
print('My name is 
Anupam')
# Out:
#   File "<ipython-input-7-6b87626625a7>", line 1
#     print('My name is
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("My name is")
print("Anupam")
# Out:
# My name is
# Anupam

# %% [markdown]
# ***for getting a line break we use triple quote"""***

# %%
print("""My name is
Anupam""")
# Out:
# My name is
# Anupam

# %% [markdown]
# **Print the given statement:-**
# My name is "Anupam"

# %%
print("My name is "Anupam"")
# Out:
#   File "<ipython-input-10-9d2ad250818d>", line 1
#     print("My name is "Anupam"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('My name is "Anupam"')
# Out:
# My name is "Anupam"

# %% [markdown]
# My name is 'Anupam'

# %%
print("My name is 'Anupam'")
# Out:
# My name is 'Anupam'

# %% [markdown]
# #**2.COMMENTS**

# %%
#This is a comment

# %%
#This is a comment before print statement.
#Below you can see the code for printing your "NAME".
print("My name is Anupam")
# Out:
# My name is Anupam

# %%
"""This is a multiline
comment"""
print("My name is Anupam")
# Out:
# My name is Anupam

# %% [markdown]
# #**3.INDENTATION**

# %% [markdown]
# ***indentation error***

# %%
print("Hai")
 print("Anupam")
# Out:
#   File "<ipython-input-17-5c3af8c397be>", line 2
#     print("Anupam")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **python has  a strict format incase of indentation!!!**

# %%
print("hai")
print("Anupam")
