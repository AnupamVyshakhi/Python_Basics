# %% [markdown]
# #**2.**

# %%
if(True):
# Out:
#   File "<ipython-input-1-1b027c28ed2a>", line 1
#     if(True):
#              ^
# SyntaxError: incomplete input

# %%
a=11
print(a>10)
# Out:
# True

# %%
if (True):
  print("True1")
print("True 2")
print("hai")
# Out:
# True1
# True 2
# hai

# %%
a=50
if(a>80):
  print("PASSED")
if(a<80):
  print("FAILED")
# Out:
# FAILED

# %% [markdown]
# #**3.ELSE IF**

# %%
a=50
if(a>80):
  print("PASSED")
else:
  print("FAILED")
# Out:
# FAILED

# %% [markdown]
# #**4.NESTED IF**

# %%
a=91
if(a>80):
  print("PASSED")
  if(a>90):
    print("A+")
else:
  print("FAILED")
# Out:
# PASSED
# A+

# %% [markdown]
# #**5.ELIF**

# %%
a=int(input("ENTER A NUMBER BETWEEN 1 TO 4 \n"))
if(a==1):
  print("ONE!!!")
if(a==2):
  print("TWO!!!")
if(a==3):
  print("THREE!!!")
if(a==4):
  print("FOUR!!!")
# Out:
# ENTER A NUMBER BETWEEN 1 TO 4
# 2
# TWO!!!

# %%
a=int(input("ENTER A NUMBER BETWEEN 1 TO 4 \n"))
if(a==1):
  print("ONE!!!")
elif(a==2):
  print("TWO!!!")
elif(a==3):
  print("THREE!!!")
elif(a==4):
  print("FOUR!!!")
else:
  print("FALSE INPUT!!!")
# Out:
# ENTER A NUMBER BETWEEN 1 TO 4
# 5
# FALSE INPUT!!!

# %%
dict1 = {"key1":1, "key2":2}
dict2 = {"key2":2, "key1":1}
print(dict1 == dict2)
# Out:
# True
