# %% [markdown]
# #**TUPLE**

# %% [markdown]
# tuple is not mutable but list is mutable

# %%
a=(1,2,3,4,5)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# **PROPERTIES**

# %% [markdown]
# **1. Get a value**

# %%
a=(1,2,3,4,5)
print(a[2])
# Out:
# 3

# %% [markdown]
# **2. Change Value**

# %%
a[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-50b251620e63> in <cell line: 1>()
# ----> 1 a[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **METHODS AVAILABLE**

# %% [markdown]
# **Count**

# %%
b=(200,300,100,200,300,300)
b.count(300)
# Out:
# 3

# %%
b.count(200)
# Out:
# 2

# %%
b.count(100)
# Out:
# 1

# %%
b.count(500)
# Out:
# 0

# %% [markdown]
# **Index**

# %%
b.index(300)
# Out:
# 1

# %%
b.index(200)
# Out:
# 0

# %% [markdown]
# index shows first index of that value.

# %%
b.index(100)
# Out:
# 2

# %%
b.index(500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-41e96554bae2> in <cell line: 1>()
# ----> 1 b.index(500)
#
# ValueError: tuple.index(x): x not in tuple

# %%
c=(1,2,"ANUPAM")
print(c)
# Out:
# (1, 2, 'ANUPAM')

# %%
b=(10,20,30,40,50,60,(100,200,300))
c=(1,2,3,4)
print(b+c)
# Out:
# (10, 20, 30, 40, 50, 60, (100, 200, 300), 1, 2, 3, 4)

# %%
a=(10,20,30,40,50,60,(100,200,300),1,2,3,4)
print(a[6])
# Out:
# (100, 200, 300)
