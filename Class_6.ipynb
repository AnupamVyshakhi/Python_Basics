# %% [markdown]
# #**PYTHON DATAYPES**
#
# 1.None
#
# 2.Numeric
#
# 3.List
#
# 4.Tuple
#
# 5.Set
#
# 6.Range
#
# 7.String
#
# 8.Dictionary

# %% [markdown]
# #**1.LIST**

# %%
a=[1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
b=[1,"Anupam",5.67]
print(b)
# Out:
# [1, 'Anupam', 5.67]

# %%
print(type(b ))
# Out:
# <class 'list'>

# %%
print(b[1])
# Out:
# Anupam

# %%
print(b[1:3:1])
# Out:
# ['Anupam', 5.67]

# %%
print(b[0:2:1])
# Out:
# [1, 'Anupam']

# %% [markdown]
# #**2.NESTED LIST**

# %%
c=[1,2,3,[4,5,6]]
print(c)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
print(c[3][1])
print(c[3][0])
# Out:
# 5
# 4

# %% [markdown]
# #**3.LIST OPERATIONS**

# %% [markdown]
# **1.APPEND**

# %%
l=[1,2,3]
print(l)
# Out:
# [1, 2, 3]

# %%
l.append(4)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.append(5)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **2.INSERT**

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5]

# %% [markdown]
# **3.REMOVE**

# %%
l.remove(8)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **4.POP**

# %%
l.pop(2)
print(l)
# Out:
# [1, 2, 4, 5]

# %%
l.pop()
print(l)
# Out:
# [1, 2]

# %% [markdown]
# **5.DEL**

# %%
l.insert(2,3)
print(l)
# Out:
# [1, 2, 3]

# %%
l.append(4)
print(l)
# Out:
# [1, 2, 4]

# %%
print(l)
# Out:
# [1, 2, 4]

# %%
l.insert(2,3)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.append(5)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# **5.DEL**

# %%
l=[1,2,3,4,5]
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
del l[1:4]
print(l)
# Out:
# [1, 5]

# %% [markdown]
# **6.INSERT MULTIPLE VALUES**

# %%
l.extend([9,13,17,22])
print(l)
# Out:
# [1, 5, 9, 13, 17, 22]

# %% [markdown]
# **7.SORT**

# %% [markdown]
# Sorting will defaultly ascending.If we need descending name.sort(reverse=True)

# %%
z=[30,25,10,15,55,40,45]
z.sort()
print(z)
# Out:
# [10, 15, 25, 30, 40, 45, 55]

# %% [markdown]
# **8.MINIMUM**

# %%
min(z)
# Out:
# 10

# %% [markdown]
# **9.MAXIMUM**

# %%
max(z)
# Out:
# 55

# %% [markdown]
# **10.SUM**

# %%
sum(z)
# Out:
# 220
