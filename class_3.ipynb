# %% [markdown]
# #**1.ARITHMETIC OPERATION**

# %% [markdown]
# **1.1ADDITION**

# %%
2+3
# Out:
# 5

# %%
print(3+5)
# Out:
# 8

# %% [markdown]
# **1.2SUBTRACTION**

# %%
print(9-4)
# Out:
# 5

# %% [markdown]
# **1.3MULTIPLICATION**

# %%
print(3*2)
# Out:
# 6

# %% [markdown]
# **1.4DIVISION**

# %%
print(6/3)
# Out:
# 2.0

# %% [markdown]
# ***TO REMOVE THE DIGIT AFTER POINT***

# %%
print(6//4)
# Out:
# 1

# %%
print(4//2)
# Out:
# 2

# %% [markdown]
# **1.5POWER OF AN EXPONENT**

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# **1.6MODULUS**

# %%
print(8%2)
# Out:
# 0

# %%
print(10%6)
# Out:
# 4

# %% [markdown]
# #**2.VARIABLES IN PYTHON**

# %%
a=10
print(a)
# Out:
# 10

# %%
#1.Int
a=6
print(a)
# Out:
# 6

# %%
#Float
#Eg 2.3, 4.5
b=2.3
print(b)
# Out:
# 2.3

# %%
#String
s="Anupam"
print(s)
c='Vyshakhi S'
print(c)
# Out:
# Anupam
# Vyshakhi S

# %%
#Boolean
d=True
print(d)
# Out:
# True

# %% [markdown]
# **1.Variable names should start with alphabets**.

# %%
mark=100
print(mark)
# Out:
# 100

# %%
1mark=100
print(mark)
# Out:
#   File "<ipython-input-20-4517ec2aecd3>", line 1
#     1mark=100
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **2.Variable name should not conatin any special characters like !@#$%^&*().**

# %%
m@rk=100
print(mark)
# Out:
#   File "<ipython-input-21-a56654c5d3e8>", line 1
#     m@rk=100
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# **3.Variable names can conatin numbers but you can't start with numbers.**

# %%
mark6=100
print(mark)
# Out:
# 100

# %%
4mark=100
print(mark)
# Out:
#   File "<ipython-input-23-f817ebee1076>", line 1
#     4mark=100
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# **4.It's not a strict rule that you should variable names start with a Capital letters recommended to use small letters**

# %%
Mark=100
print(Mark)
# Out:
# 100

# %%
Mark=100
m=Mark
print(m)
# Out:
# 100

# %% [markdown]
# **5.No space in between variable names**

# %%
mark student=100
print(mark student)
# Out:
#   File "<ipython-input-26-c3596275a9a5>", line 1
#     mark student=100
#          ^
# SyntaxError: invalid syntax

# %%
mark_student=100
print(mark_student)
# Out:
# 100

# %%
_a=10
_b=9
print(_a-_b)
# Out:
# 1

# %%
5//2
# Out:
# 2

# %%
5/2
# Out:
# 2.5

# %%
_a=10
print(_a)
# Out:
# 10

# %%
m=10
print("f name is {m}")
# Out:
# f name is {m}
