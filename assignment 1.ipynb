# %% [markdown]
# **Create and upload a goofle colab file int the below format:-**
#
# 1.Create a google colab file.
#
# 2.Rename the file into assignment 1.
#
# 3.Create a text block and write down the question.
#
# 4.Create a code block.
#
# 5.Add two numbers(As shown in the previous video).
#
# 6.Download the file in .ipynb format.
#
# 7.Upload the file google classroom assignment.

# %%
3+5
# Out:
# 8
