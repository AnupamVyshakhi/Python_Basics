# %% [markdown]
# #**1.STRING**

# %%
a="Anupam"
print(type(a))
# Out:
# <class 'str'>

# %%
b="***&%$#^"
print(type(b))
# Out:
# <class 'str'>

# %% [markdown]
# **1.1 STRING INDEXING**
# 1.Positive Indexing
#
# 2.Negative Indexing

# %%
a="Anupam"
print(a[0])
print(a[5])
print(a[-1])
print(a[-6])
print(a[-5])
# Out:
# A
# m
# m
# A
# n

# %% [markdown]
# **1.2 STRING SLICING**

# %% [markdown]
# **SYNTAX**
#
# [start : ending : step]

# %%
a="Anupam"
print(a[1:5:1])
# Out:
# nupa

# %%
print(a[2:4:1])
# Out:
# up

# %%
print(a[0:5:2])
# Out:
# Aua

# %%
print(a[0:5:3])
# Out:
# Ap

# %% [markdown]
# **1.NO step size**

# %%
a="Anupam"
print(a[1:3])
# Out:
# nu

# %% [markdown]
# **2.NO Stop Index**

# %%
a="Anupam"
print(a[1::2])
# Out:
# npm

# %% [markdown]
# **3.NO start index**

# %%
a="Anupam"
print(a[:5:2])
# Out:
# Aua

# %% [markdown]
# 4.No start No stop index

# %%
a="Anupam"
print(a[::2])
# Out:
# Aua

# %% [markdown]
# 5.NO start NO stop No step index

# %%
a="Anupam"
print(a[::])
# Out:
# Anupam
