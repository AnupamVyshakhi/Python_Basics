# %% [markdown]
# #**1.USER INPUT**

# %%
a=input()
# Out:
# 5

# %%
a=input()
b=input()
sum=a+b;
print(sum)
# Out:
# 6
# 1
# 61

# %%
b=input("ENTER YOUR NAME: ")
print(b)
# Out:
# ENTER YOUR NAME: Aninditha
# Aninditha

# %%
c="Anupam"
print(c)
# Out:
# Anupam

# %%
num1=input("ENTER THE FIRST NUMBER: ")
num2=input("ENTER THE SECOND NUMBER: ")
sum=num1+num2
print(sum)
# Out:
# ENTER THE FIRST NUMBER: 5
# ENTER THE SECOND NUMBER: 4
# 54

# %%
num1=input("ENTER THE FIRST NUMBER: ")
print(type(num1))
# Out:
# ENTER THE FIRST NUMBER: 10
# <class 'str'>

# %%
a="MY NAME IS "
b="ANUPAM"
str=a+b
print(str)
# Out:
# MY NAME IS ANUPAM

# %% [markdown]
# #**2.TYPECASTING**

# %%
a=10.2
print(type(a))
# Out:
# <class 'float'>

# %%
b=int(a)
print(b)
type(b)
# Out:
# 10
# int

# %%
 b=10

# %%
j=str(b)
print(j)
print(type(j))
# Out:
# 10
# <class 'str'>

# %%
num1=int(input("ENTER THE FIRST NUMBER: "))
num2=int(input("ENTER THE SECOND NUMBER: "))
sum=num1+num2
print(sum)
# Out:
# ENTER THE FIRST NUMBER: 6
# ENTER THE SECOND NUMBER: 4
# 10

# %% [markdown]
# #**3.APPLING SLICING AND INDEXING ON INPUT STATEMENT**

# %%
n=input("ENTER YOUR NAME: ")
print(n[3:6:1])
print(n[0])
# Out:
# ENTER YOUR NAME: Anupam
# pam
# A

# %%
n=input("ENTER YOUR NAME: ")[0]
print(n)
# Out:
# ENTER YOUR NAME: Anupam
# A

# %% [markdown]
# #**4.Eval()**

# %%
a=eval(input("ENTER YOUR ADDITION OPERATIONS"))
print(a)
# Out:
# ENTER YOUR ADDITION OPERATIONS2+3
# 5

# %%
x=5
result=eval('2*x+3')
print(result)
# Out:
# 13
